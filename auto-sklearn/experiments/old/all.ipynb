# %%
mlp_accuracy = [0.768, 0.768, 0.768, 0.776, 0.784]
mlp_precision = [0.7631578947368421, 0.7631578947368421, 0.7631578947368421, 0.7560975609756098, 0.7894736842105263]
mlp_recall = [0.5918367346938775, 0.5918367346938775, 0.5918367346938775, 0.6326530612244898, 0.6122448979591837]

# %%
rf_accuracy = [0.608, 0.72, 0.72, 0.736, 0.736]
rf_precision = [0.0, 0.7058823529411765, 0.7058823529411765, 0.75, 0.75]
rf_recall = [0.0, 0.4897959183673469, 0.4897959183673469, 0.4897959183673469, 0.4897959183673469]

# %%
mlp_rf_cleaned_accuracy = [0.82, 0.83, 0.83, 0.82, 0.8]
mlp_rf_cleaned_precision = [0.7586206896551724, 0.7857142857142857, 0.7857142857142857, 0.7419354838709677, 0.696969696969697]
mlp_rf_cleaned_recall = [0.6666666666666666, 0.6666666666666666, 0.6666666666666666, 0.696969696969697, 0.696969696969697]

# %%
import matplotlib.pyplot as plt

time_budget = [30, 40, 60, 90, 120]
plt.plot(time_budget, mlp_accuracy, marker='o', label='MLP')
plt.plot(time_budget, mlp_rf_cleaned_accuracy, marker='x', label='MLP with RF cleaned')
plt.title('Time Budget vs. Accuracy')
plt.legend()
plt.ylabel('Accuracy')
plt.xlabel('Time Budget')
# Out:
# Text(0.5, 0, 'Time Budget')

# %%
import matplotlib.pyplot as plt

time_budget = [30, 40, 60, 90, 120]
plt.plot(time_budget, mlp_recall, marker='o', label='MLP')
plt.plot(time_budget, mlp_rf_cleaned_recall, marker='x', label='MLP with RF cleaned')
plt.title('Time Budget vs. Recall')
plt.legend()
plt.ylabel('Recall')
plt.xlabel('Time Budget')
# Out:
# Text(0.5, 0, 'Time Budget')

# %%
import matplotlib.pyplot as plt

time_budget = [30, 40, 60, 90, 120]
plt.plot(time_budget, mlp_precision, marker='o', label='MLP')
plt.plot(time_budget, mlp_rf_cleaned_precision, marker='x', label='MLP with RF cleaned')
plt.title('Time Budget vs. Recall')
plt.legend()
plt.ylabel('Recall')
plt.xlabel('Time Budget')
# Out:
# Text(0.5, 0, 'Time Budget')

# %%
mlp_lda_cleaned_accuracy = [0.8, 0.79, 0.8, 0.82, 0.82]
mlp_lda_cleaned_precision = [0.782608695652174, 0.7307692307692307, 0.76, 0.8260869565217391, 0.7777777777777778]
mlp_lda_cleaned_recall = [0.5454545454545454, 0.5757575757575758, 0.5757575757575758, 0.5757575757575758, 0.6363636363636364]

# %%
import matplotlib.pyplot as plt

time_budget = [30, 40, 60, 90, 120]
plt.plot(time_budget, mlp_accuracy, marker='o', label='MLP')
plt.plot(time_budget, mlp_lda_cleaned_accuracy, marker='x', label='MLP with LDA cleaned')
plt.title('Time Budget vs. Acuuracy')
plt.legend()
plt.ylabel('Accuracy')
plt.xlabel('Time Budget')
# Out:
# Text(0.5, 0, 'Time Budget')

# %%
import matplotlib.pyplot as plt

time_budget = [30, 40, 60, 90, 120]
plt.plot(time_budget, mlp_precision, marker='o', label='MLP')
plt.plot(time_budget, mlp_lda_cleaned_precision, marker='x', label='MLP with LDA cleaned')
plt.title('Time Budget vs. Precision')
plt.legend()
plt.ylabel('Precision')
plt.xlabel('Time Budget')
# Out:
# Text(0.5, 0, 'Time Budget')

# %%
import matplotlib.pyplot as plt

time_budget = [30, 40, 60, 90, 120]
plt.plot(time_budget, mlp_recall, marker='o', label='MLP')
plt.plot(time_budget, mlp_lda_cleaned_recall, marker='x', label='MLP with LDA cleaned')
plt.title('Time Budget vs. Recall')
plt.legend()
plt.ylabel('Recall')
plt.xlabel('Time Budget')
# Out:
# Text(0.5, 0, 'Time Budget')
